# %% [markdown]
# ### Imports ###

# %%
import optuna
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

import tensorboardX

# %% [markdown]
# ### Aufsetzen des Cart-Pole-Environments ###

# %%
env = gym.make('CartPole-v1')

# %% [markdown]
# ### Initiale Hyperparameter Definition ###

# %%
LOG_DIR = "logs"
VERBOSE = 1
TOTAL_TIMESTEPS = 40000
N_EVAL_EPISODES = 10
N_TRIALS = 10

# %% [markdown]
# ### Baseline PPO-Agent ###

# %%
# Initialisierung des Modells
model = PPO('MlpPolicy', env, verbose=VERBOSE, tensorboard_log=LOG_DIR)

# Trainieren des Modells
model.learn(total_timesteps=TOTAL_TIMESTEPS)

# Evaluierung des Modells
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=N_EVAL_EPISODES)

print(f"Mean reward: {mean_reward}, std deviation: {std_reward}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | 22       |
# | time/              |          |
# |    fps             | 492      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.7        |
# |    ep_rew_mean          | 26.7        |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009360518 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | -0.00082    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.43        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 50.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.4        |
# |    ep_rew_mean          | 34.4        |
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012335967 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 35.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45          |
# |    ep_rew_mean          | 45          |
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 4           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008122886 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.635      |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 52.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.9        |
# |    ep_rew_mean          | 58.9        |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 5           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008766886 |
# |    clip_fraction        | 0.0808      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.614      |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 61.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 73.7       |
# |    ep_rew_mean          | 73.7       |
# | time/                   |            |
# |    fps                  | 338        |
# |    iterations           | 6          |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00751481 |
# |    clip_fraction        | 0.0681     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.587     |
# |    explained_variance   | 0.281      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.7       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0164    |
# |    value_loss           | 71.8       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.7         |
# |    ep_rew_mean          | 89.7         |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 7            |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0046962346 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.579       |
# |    explained_variance   | 0.433        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.1         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00748     |
# |    value_loss           | 60.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 320         |
# |    iterations           | 8           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006646349 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.559      |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.1        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 57          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 124         |
# |    ep_rew_mean          | 124         |
# | time/                   |             |
# |    fps                  | 317         |
# |    iterations           | 9           |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008417919 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.565      |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.15        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 28          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 142          |
# |    ep_rew_mean          | 142          |
# | time/                   |              |
# |    fps                  | 318          |
# |    iterations           | 10           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0073723663 |
# |    clip_fraction        | 0.0582       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.575       |
# |    explained_variance   | 0.892        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.74         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00625     |
# |    value_loss           | 19.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 157          |
# |    ep_rew_mean          | 157          |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 11           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0066658854 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.548       |
# |    explained_variance   | 0.54         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.5         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00396     |
# |    value_loss           | 31.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | 178          |
# | time/                   |              |
# |    fps                  | 309          |
# |    iterations           | 12           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0045715747 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.55        |
# |    explained_variance   | 0.93         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.94         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00771     |
# |    value_loss           | 12.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 194          |
# |    ep_rew_mean          | 194          |
# | time/                   |              |
# |    fps                  | 311          |
# |    iterations           | 13           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0019986783 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.546       |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.362        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00405     |
# |    value_loss           | 5.47         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 212          |
# |    ep_rew_mean          | 212          |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 14           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0021706587 |
# |    clip_fraction        | 0.00942      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.534       |
# |    explained_variance   | 0.0178       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.645        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 21.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 229          |
# |    ep_rew_mean          | 229          |
# | time/                   |              |
# |    fps                  | 295          |
# |    iterations           | 15           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0055549247 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.522       |
# |    explained_variance   | 0.171        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 2.43         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 249        |
# |    ep_rew_mean          | 249        |
# | time/                   |            |
# |    fps                  | 295        |
# |    iterations           | 16         |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.00897971 |
# |    clip_fraction        | 0.0584     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.508     |
# |    explained_variance   | -0.0757    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.072      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00201   |
# |    value_loss           | 1.17       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 265          |
# |    ep_rew_mean          | 265          |
# | time/                   |              |
# |    fps                  | 295          |
# |    iterations           | 17           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0045578997 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.51        |
# |    explained_variance   | -0.00615     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0477       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 0.779        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 282          |
# |    ep_rew_mean          | 282          |
# | time/                   |              |
# |    fps                  | 289          |
# |    iterations           | 18           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0027323682 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.504       |
# |    explained_variance   | 0.0174       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0694       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000631    |
# |    value_loss           | 0.497        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 299          |
# |    ep_rew_mean          | 299          |
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 19           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0036549554 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.515       |
# |    explained_variance   | -0.00567     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0431       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000524    |
# |    value_loss           | 0.288        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 315          |
# |    ep_rew_mean          | 315          |
# | time/                   |              |
# |    fps                  | 290          |
# |    iterations           | 20           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0034572156 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.52        |
# |    explained_variance   | 0.00857      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0351       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000888    |
# |    value_loss           | 0.185        |
# ------------------------------------------
# Mean reward: 500.0, std deviation: 0.0

# %% [markdown]
# ![PPO](./img/PPO.png)

# %% [markdown]
# ### Hyperparameter Tuning ###

# %%
# Definition der Optimierungsfunktion
def optimize_ppo(trial):
    env = gym.make('CartPole-v1')
    env = DummyVecEnv([lambda: env])
    n_envs = 1

    # Definition der Hyperparameter inkl. Range
    n_steps = trial.suggest_int('n_steps', 5, 2048)
    gamma = trial.suggest_float('gamma', 0.8, 0.9999)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 0.05)
    ent_coef = trial.suggest_float('ent_coef', 1e-8, 0.1)

    # Erstellen des PPO-Modells
    model = PPO('MlpPolicy', env, n_steps=n_steps, gamma=gamma, learning_rate=learning_rate, ent_coef=ent_coef, batch_size=n_steps * n_envs, verbose=VERBOSE)
    
    # Trainieren des Modells
    model.learn(total_timesteps=TOTAL_TIMESTEPS)
    
    # Evaluierung des Modells
    mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=N_EVAL_EPISODES)

    return mean_reward

# Erstellen einer Optuna-Studie und Optimierung die Hyperparameter
study = optuna.create_study(direction='maximize')
study.optimize(optimize_ppo, n_trials=N_TRIALS)

# Ausgabe der besten Hyperparameter
print("Beste Hyperparameter: ", study.best_params)
# Out:
# [I 2024-07-26 13:11:53,114] A new study created in memory with name: no-name-bb64b5d5-04c1-411c-a236-cbf6126cfa24
# Using cpu device
# ----------------------------
# | time/              |     |
# |    fps             | 423 |
# |    iterations      | 1   |
# |    time_elapsed    | 1   |
# |    total_timesteps | 463 |
# ----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 392         |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 926         |
# | train/                  |             |
# |    approx_kl            | 0.008125198 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | 0.000667    |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.432       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 6.34        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 1389        |
# | train/                  |             |
# |    approx_kl            | 0.009552673 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.68       |
# |    explained_variance   | 0.375       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.371       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00891    |
# |    value_loss           | 1.61        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 435         |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 1852        |
# | train/                  |             |
# |    approx_kl            | 0.019944284 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.658      |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.273       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0213     |
# |    value_loss           | 0.894       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 2315        |
# | train/                  |             |
# |    approx_kl            | 0.027180396 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.652      |
# |    explained_variance   | 0.611       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.0632      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.033      |
# |    value_loss           | 0.371       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 6            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 2778         |
# | train/                  |              |
# |    approx_kl            | 0.0075181997 |
# |    clip_fraction        | 0.353        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.582       |
# |    explained_variance   | 0.423        |
# |    learning_rate        | 0.023        |
# |    loss                 | 0.239        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0156      |
# |    value_loss           | 0.866        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 500         |
# |    iterations           | 7           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 3241        |
# | train/                  |             |
# |    approx_kl            | 0.004673913 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.58       |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.139       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.396       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 510         |
# |    iterations           | 8           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 3704        |
# | train/                  |             |
# |    approx_kl            | 0.008417907 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.578      |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.0901      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 0.331       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 524        |
# |    iterations           | 9          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4167       |
# | train/                  |            |
# |    approx_kl            | 0.03928357 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.495     |
# |    explained_variance   | 0.852      |
# |    learning_rate        | 0.023      |
# |    loss                 | 0.0156     |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0228    |
# |    value_loss           | 0.15       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 535        |
# |    iterations           | 10         |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 4630       |
# | train/                  |            |
# |    approx_kl            | 0.02140326 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.531     |
# |    explained_variance   | 0.737      |
# |    learning_rate        | 0.023      |
# |    loss                 | 0.0327     |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0017    |
# |    value_loss           | 0.2        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 11          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 5093        |
# | train/                  |             |
# |    approx_kl            | 0.008888009 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.533      |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.00548     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00862     |
# |    value_loss           | 0.117       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 549        |
# |    iterations           | 12         |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 5556       |
# | train/                  |            |
# |    approx_kl            | 0.02573813 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.567     |
# |    explained_variance   | 0.614      |
# |    learning_rate        | 0.023      |
# |    loss                 | 0.0256     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00822   |
# |    value_loss           | 0.16       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 13          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6019        |
# | train/                  |             |
# |    approx_kl            | 0.012095176 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.554      |
# |    explained_variance   | -0.229      |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.203       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00403    |
# |    value_loss           | 0.696       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 553        |
# |    iterations           | 14         |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 6482       |
# | train/                  |            |
# |    approx_kl            | 0.03899621 |
# |    clip_fraction        | 0.268      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.594     |
# |    explained_variance   | 0.494      |
# |    learning_rate        | 0.023      |
# |    loss                 | 0.0937     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | 0.00946    |
# |    value_loss           | 0.279      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 15          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6945        |
# | train/                  |             |
# |    approx_kl            | 0.014049028 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.542      |
# |    explained_variance   | 0.383       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.048       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00856    |
# |    value_loss           | 0.276       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 16          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 7408        |
# | train/                  |             |
# |    approx_kl            | 0.020896517 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.622      |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.105       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 0.588       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 17          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 7871        |
# | train/                  |             |
# |    approx_kl            | 0.057328854 |
# |    clip_fraction        | 0.542       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.46       |
# |    explained_variance   | 0.559       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.0959      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00788     |
# |    value_loss           | 0.325       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 558        |
# |    iterations           | 18         |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 8334       |
# | train/                  |            |
# |    approx_kl            | 0.01992323 |
# |    clip_fraction        | 0.319      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.617     |
# |    explained_variance   | 0.226      |
# |    learning_rate        | 0.023      |
# |    loss                 | 0.0727     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0033    |
# |    value_loss           | 0.287      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 19          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 8797        |
# | train/                  |             |
# |    approx_kl            | 0.011143743 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.0362      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00114    |
# |    value_loss           | 0.194       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 558        |
# |    iterations           | 20         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 9260       |
# | train/                  |            |
# |    approx_kl            | 0.00533789 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.623     |
# |    explained_variance   | 0.0753     |
# |    learning_rate        | 0.023      |
# |    loss                 | 0.427      |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.000129   |
# |    value_loss           | 1.11       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 21          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 9723        |
# | train/                  |             |
# |    approx_kl            | 0.034710325 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.629      |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.12        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00982    |
# |    value_loss           | 0.663       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 22          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 10186       |
# | train/                  |             |
# |    approx_kl            | 0.040246896 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | 0.0279      |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.183       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0068     |
# |    value_loss           | 0.474       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 23          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 10649       |
# | train/                  |             |
# |    approx_kl            | 0.027962783 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.0397      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.000736   |
# |    value_loss           | 0.188       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 561         |
# |    iterations           | 24          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 11112       |
# | train/                  |             |
# |    approx_kl            | 0.008533956 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | 0.532       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.0348      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00371    |
# |    value_loss           | 0.188       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 563         |
# |    iterations           | 25          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 11575       |
# | train/                  |             |
# |    approx_kl            | 0.008553109 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.572      |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.00696     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00532    |
# |    value_loss           | 0.15        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 563        |
# |    iterations           | 26         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 12038      |
# | train/                  |            |
# |    approx_kl            | 0.00902223 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.548     |
# |    explained_variance   | 0.367      |
# |    learning_rate        | 0.023      |
# |    loss                 | -0.0266    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.00569   |
# |    value_loss           | 0.0539     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 27           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 12501        |
# | train/                  |              |
# |    approx_kl            | 0.0064172894 |
# |    clip_fraction        | 0.0847       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.6         |
# |    explained_variance   | 0.306        |
# |    learning_rate        | 0.023        |
# |    loss                 | -0.024       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 0.0619       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 28          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 12964       |
# | train/                  |             |
# |    approx_kl            | 0.011963278 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.543      |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.0504      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00139    |
# |    value_loss           | 0.201       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 29          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 13427       |
# | train/                  |             |
# |    approx_kl            | 0.011297862 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.55       |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.0207      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00663     |
# |    value_loss           | 0.146       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 30          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 13890       |
# | train/                  |             |
# |    approx_kl            | 0.028750917 |
# |    clip_fraction        | 0.376       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.502      |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.023       |
# |    loss                 | -0.00646    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00222     |
# |    value_loss           | 0.105       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 31          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 14353       |
# | train/                  |             |
# |    approx_kl            | 0.021924274 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.589      |
# |    explained_variance   | 0.332       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.0371      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00264     |
# |    value_loss           | 0.261       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 32          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 14816       |
# | train/                  |             |
# |    approx_kl            | 0.020633364 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.567      |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.149       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00541     |
# |    value_loss           | 0.403       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 33          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 15279       |
# | train/                  |             |
# |    approx_kl            | 0.038699627 |
# |    clip_fraction        | 0.391       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.511      |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.012       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00843     |
# |    value_loss           | 0.108       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 34          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 15742       |
# | train/                  |             |
# |    approx_kl            | 0.035892736 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.584      |
# |    explained_variance   | 0.453       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.125       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.000414   |
# |    value_loss           | 0.332       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 571          |
# |    iterations           | 35           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 16205        |
# | train/                  |              |
# |    approx_kl            | 0.0076913666 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.569       |
# |    explained_variance   | 0.245        |
# |    learning_rate        | 0.023        |
# |    loss                 | 0.319        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 0.629        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 36          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 16668       |
# | train/                  |             |
# |    approx_kl            | 0.017916504 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.0626      |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.489       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 1.19        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 37          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 17131       |
# | train/                  |             |
# |    approx_kl            | 0.029915242 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.555      |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.294       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.734       |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 567       |
# |    iterations           | 38        |
# |    time_elapsed         | 31        |
# |    total_timesteps      | 17594     |
# | train/                  |           |
# |    approx_kl            | 0.0397002 |
# |    clip_fraction        | 0.321     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.566    |
# |    explained_variance   | 0.218     |
# |    learning_rate        | 0.023     |
# |    loss                 | -0.00826  |
# |    n_updates            | 370       |
# |    policy_gradient_loss | -0.0104   |
# |    value_loss           | 0.142     |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 39          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 18057       |
# | train/                  |             |
# |    approx_kl            | 0.042918716 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.597      |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.145       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.000251   |
# |    value_loss           | 0.37        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 40          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 18520       |
# | train/                  |             |
# |    approx_kl            | 0.012763509 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.051       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00147     |
# |    value_loss           | 0.191       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 563        |
# |    iterations           | 41         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 18983      |
# | train/                  |            |
# |    approx_kl            | 0.04094936 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.548     |
# |    explained_variance   | 0.597      |
# |    learning_rate        | 0.023      |
# |    loss                 | 0.0471     |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00896   |
# |    value_loss           | 0.213      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 42          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 19446       |
# | train/                  |             |
# |    approx_kl            | 0.028185103 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.586      |
# |    explained_variance   | 0.56        |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.111       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0013     |
# |    value_loss           | 0.262       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 43          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 19909       |
# | train/                  |             |
# |    approx_kl            | 0.061528813 |
# |    clip_fraction        | 0.343       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | 0.387       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.0382      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00248     |
# |    value_loss           | 0.287       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 44          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 20372       |
# | train/                  |             |
# |    approx_kl            | 0.012802483 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.567      |
# |    explained_variance   | -0.81       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.128       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00379    |
# |    value_loss           | 0.539       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 45          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 20835       |
# | train/                  |             |
# |    approx_kl            | 0.056195814 |
# |    clip_fraction        | 0.525       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.438      |
# |    explained_variance   | -0.0543     |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.151       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.0117      |
# |    value_loss           | 0.333       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 46          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 21298       |
# | train/                  |             |
# |    approx_kl            | 0.033752024 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | -8.67       |
# |    learning_rate        | 0.023       |
# |    loss                 | -0.00694    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.000469    |
# |    value_loss           | 0.0498      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 47          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 21761       |
# | train/                  |             |
# |    approx_kl            | 0.023329621 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.531      |
# |    explained_variance   | -3.21       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.0452      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.0101      |
# |    value_loss           | 0.425       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 48          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 22224       |
# | train/                  |             |
# |    approx_kl            | 0.047076717 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.0847      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -8.6e-06    |
# |    value_loss           | 0.253       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 49          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 22687       |
# | train/                  |             |
# |    approx_kl            | 0.037568238 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | -12.9       |
# |    learning_rate        | 0.023       |
# |    loss                 | -0.0351     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00167    |
# |    value_loss           | 0.00115     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 548        |
# |    iterations           | 50         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 23150      |
# | train/                  |            |
# |    approx_kl            | 0.06412111 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.591     |
# |    explained_variance   | 0.193      |
# |    learning_rate        | 0.023      |
# |    loss                 | 0.32       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | 9.78e-05   |
# |    value_loss           | 0.711      |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 550       |
# |    iterations           | 51        |
# |    time_elapsed         | 42        |
# |    total_timesteps      | 23613     |
# | train/                  |           |
# |    approx_kl            | 0.0166466 |
# |    clip_fraction        | 0.119     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.601    |
# |    explained_variance   | 0.41      |
# |    learning_rate        | 0.023     |
# |    loss                 | 0.1       |
# |    n_updates            | 500       |
# |    policy_gradient_loss | -0.000587 |
# |    value_loss           | 0.266     |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 552          |
# |    iterations           | 52           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 24076        |
# | train/                  |              |
# |    approx_kl            | 0.0113852555 |
# |    clip_fraction        | 0.143        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.582       |
# |    explained_variance   | 0.0565       |
# |    learning_rate        | 0.023        |
# |    loss                 | 0.719        |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0244      |
# |    value_loss           | 1.65         |
# ------------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 553      |
# |    iterations           | 53       |
# |    time_elapsed         | 44       |
# |    total_timesteps      | 24539    |
# | train/                  |          |
# |    approx_kl            | 0.145103 |
# |    clip_fraction        | 0.438    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.559   |
# |    explained_variance   | 0.207    |
# |    learning_rate        | 0.023    |
# |    loss                 | 0.272    |
# |    n_updates            | 520      |
# |    policy_gradient_loss | 0.00975  |
# |    value_loss           | 0.609    |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 54          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 25002       |
# | train/                  |             |
# |    approx_kl            | 0.079688706 |
# |    clip_fraction        | 0.398       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.489      |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.11        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.00728     |
# |    value_loss           | 0.308       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 55          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 25465       |
# | train/                  |             |
# |    approx_kl            | 0.053029884 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | 0.742       |
# |    learning_rate        | 0.023       |
# |    loss                 | -0.00209    |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00531    |
# |    value_loss           | 0.0838      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 557        |
# |    iterations           | 56         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 25928      |
# | train/                  |            |
# |    approx_kl            | 0.02675961 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.585     |
# |    explained_variance   | 0.664      |
# |    learning_rate        | 0.023      |
# |    loss                 | -0.0203    |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.00962   |
# |    value_loss           | 0.0626     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 57          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 26391       |
# | train/                  |             |
# |    approx_kl            | 0.018963315 |
# |    clip_fraction        | 0.371       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | -0.00157    |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.0567      |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00045    |
# |    value_loss           | 0.171       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 559        |
# |    iterations           | 58         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 26854      |
# | train/                  |            |
# |    approx_kl            | 0.05810622 |
# |    clip_fraction        | 0.337      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.501     |
# |    explained_variance   | -3.25      |
# |    learning_rate        | 0.023      |
# |    loss                 | 0.0305     |
# |    n_updates            | 570        |
# |    policy_gradient_loss | 0.0337     |
# |    value_loss           | 0.115      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 561        |
# |    iterations           | 59         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 27317      |
# | train/                  |            |
# |    approx_kl            | 0.09606278 |
# |    clip_fraction        | 0.511      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.445     |
# |    explained_variance   | -0.0981    |
# |    learning_rate        | 0.023      |
# |    loss                 | 0.944      |
# |    n_updates            | 580        |
# |    policy_gradient_loss | 0.0425     |
# |    value_loss           | 1.82       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 558        |
# |    iterations           | 60         |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 27780      |
# | train/                  |            |
# |    approx_kl            | 0.02654317 |
# |    clip_fraction        | 0.275      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.474     |
# |    explained_variance   | -9.54e-07  |
# |    learning_rate        | 0.023      |
# |    loss                 | 1.02       |
# |    n_updates            | 590        |
# |    policy_gradient_loss | 0.0174     |
# |    value_loss           | 1.98       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 554        |
# |    iterations           | 61         |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 28243      |
# | train/                  |            |
# |    approx_kl            | 0.17998526 |
# |    clip_fraction        | 0.54       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.416     |
# |    explained_variance   | 6.2e-06    |
# |    learning_rate        | 0.023      |
# |    loss                 | 1.17       |
# |    n_updates            | 600        |
# |    policy_gradient_loss | 0.058      |
# |    value_loss           | 2.42       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 62          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 28706       |
# | train/                  |             |
# |    approx_kl            | 0.014965046 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.44       |
# |    explained_variance   | -1.43e-06   |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.91        |
# |    n_updates            | 610         |
# |    policy_gradient_loss | 0.00667     |
# |    value_loss           | 1.87        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 547        |
# |    iterations           | 63         |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 29169      |
# | train/                  |            |
# |    approx_kl            | 0.01382575 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.454     |
# |    explained_variance   | -1.19e-06  |
# |    learning_rate        | 0.023      |
# |    loss                 | 0.86       |
# |    n_updates            | 620        |
# |    policy_gradient_loss | 0.000372   |
# |    value_loss           | 1.75       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 64          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 29632       |
# | train/                  |             |
# |    approx_kl            | 0.025762748 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.414      |
# |    explained_variance   | 1.19e-05    |
# |    learning_rate        | 0.023       |
# |    loss                 | 0.629       |
# |    n_updates            | 630         |
# |    policy_gradient_loss | 0.00268     |
# |    value_loss           | 1.33        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 65          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 30095       |
# | train/                  |             |
# |    approx_kl            | 0.026913064 |
# ...
# |    entropy_loss         | -0.484      |
# |    explained_variance   | 0.0189      |
# |    learning_rate        | 0.0318      |
# |    loss                 | 1.44        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00434    |
# |    value_loss           | 3.15        |
# -----------------------------------------
# [I 2024-07-26 13:20:02,982] Trial 8 finished with value: 485.0 and parameters: {'n_steps': 839, 'gamma': 0.8929122709783177, 'learning_rate': 0.03181455625786926, 'ent_coef': 0.0503659999980605}. Best is trial 7 with value: 500.0.
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 1386 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 1978 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1335         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 3956         |
# | train/                  |              |
# |    approx_kl            | 0.0092349425 |
# |    clip_fraction        | 0.211        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.677       |
# |    explained_variance   | -0.0158      |
# |    learning_rate        | 0.0435       |
# |    loss                 | 1.35         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | 0.00196      |
# |    value_loss           | 10.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1329         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 5934         |
# | train/                  |              |
# |    approx_kl            | 0.0058600954 |
# |    clip_fraction        | 0.218        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.66        |
# |    explained_variance   | 0.236        |
# |    learning_rate        | 0.0435       |
# |    loss                 | 1.37         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.013       |
# |    value_loss           | 3.96         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1300        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 7912        |
# | train/                  |             |
# |    approx_kl            | 0.012989148 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.0435      |
# |    loss                 | 1.01        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 3.22        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1284        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 9890        |
# | train/                  |             |
# |    approx_kl            | 0.056011427 |
# |    clip_fraction        | 0.441       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.516      |
# |    explained_variance   | 0.542       |
# |    learning_rate        | 0.0435      |
# |    loss                 | 0.604       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 1.79        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1285        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 11868       |
# | train/                  |             |
# |    approx_kl            | 0.045402925 |
# |    clip_fraction        | 0.46        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.514      |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.0435      |
# |    loss                 | 0.262       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.0414      |
# |    value_loss           | 0.515       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1284        |
# |    iterations           | 7           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 13846       |
# | train/                  |             |
# |    approx_kl            | 0.046222735 |
# |    clip_fraction        | 0.281       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.519      |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0435      |
# |    loss                 | 0.41        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00979     |
# |    value_loss           | 1.16        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1289        |
# |    iterations           | 8           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 15824       |
# | train/                  |             |
# |    approx_kl            | 0.039091922 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 0.0435      |
# |    loss                 | 0.288       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00667     |
# |    value_loss           | 0.312       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 9           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 17802       |
# | train/                  |             |
# |    approx_kl            | 0.027511712 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.397      |
# |    explained_variance   | 0.659       |
# |    learning_rate        | 0.0435      |
# |    loss                 | 0.118       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.00471     |
# |    value_loss           | 0.599       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1295       |
# |    iterations           | 10         |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 19780      |
# | train/                  |            |
# |    approx_kl            | 0.03862137 |
# |    clip_fraction        | 0.216      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.567     |
# |    explained_variance   | 0.821      |
# |    learning_rate        | 0.0435     |
# |    loss                 | 0.214      |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.000508  |
# |    value_loss           | 0.402      |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1296      |
# |    iterations           | 11        |
# |    time_elapsed         | 16        |
# |    total_timesteps      | 21758     |
# | train/                  |           |
# |    approx_kl            | 0.1361305 |
# |    clip_fraction        | 0.191     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.53     |
# |    explained_variance   | 0.491     |
# |    learning_rate        | 0.0435    |
# |    loss                 | 0.848     |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -0.00353  |
# |    value_loss           | 1.79      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1293       |
# |    iterations           | 12         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 23736      |
# | train/                  |            |
# |    approx_kl            | 0.02029524 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.409     |
# |    explained_variance   | 0.594      |
# |    learning_rate        | 0.0435     |
# |    loss                 | 0.168      |
# |    n_updates            | 110        |
# |    policy_gradient_loss | 0.00538    |
# |    value_loss           | 0.56       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1283       |
# |    iterations           | 13         |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 25714      |
# | train/                  |            |
# |    approx_kl            | 0.15243271 |
# |    clip_fraction        | 0.403      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.43      |
# |    explained_variance   | 0.694      |
# |    learning_rate        | 0.0435     |
# |    loss                 | 0.135      |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.0554     |
# |    value_loss           | 0.334      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1282       |
# |    iterations           | 14         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 27692      |
# | train/                  |            |
# |    approx_kl            | 0.07489587 |
# |    clip_fraction        | 0.299      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.434     |
# |    explained_variance   | 0.04       |
# |    learning_rate        | 0.0435     |
# |    loss                 | 2.4        |
# |    n_updates            | 130        |
# |    policy_gradient_loss | 0.00614    |
# |    value_loss           | 6.14       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1283       |
# |    iterations           | 15         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 29670      |
# | train/                  |            |
# |    approx_kl            | 0.09562557 |
# |    clip_fraction        | 0.429      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.351     |
# |    explained_variance   | 0.598      |
# |    learning_rate        | 0.0435     |
# |    loss                 | 0.582      |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.0627     |
# |    value_loss           | 1.32       |
# ----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 1284     |
# |    iterations           | 16       |
# |    time_elapsed         | 24       |
# |    total_timesteps      | 31648    |
# | train/                  |          |
# |    approx_kl            | 0.634553 |
# |    clip_fraction        | 0.422    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.397   |
# |    explained_variance   | 0.461    |
# |    learning_rate        | 0.0435   |
# |    loss                 | 1.02     |
# |    n_updates            | 150      |
# |    policy_gradient_loss | 0.0194   |
# |    value_loss           | 2.77     |
# --------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1274       |
# |    iterations           | 17         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 33626      |
# | train/                  |            |
# |    approx_kl            | 0.00580739 |
# |    clip_fraction        | 0.0836     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.244     |
# |    explained_variance   | 0.249      |
# |    learning_rate        | 0.0435     |
# |    loss                 | 0.377      |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.00427    |
# |    value_loss           | 3.05       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1262       |
# |    iterations           | 18         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 35604      |
# | train/                  |            |
# |    approx_kl            | 0.03645787 |
# |    clip_fraction        | 0.0931     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.308     |
# |    explained_variance   | 0.65       |
# |    learning_rate        | 0.0435     |
# |    loss                 | 0.423      |
# |    n_updates            | 170        |
# |    policy_gradient_loss | 0.00706    |
# |    value_loss           | 2.03       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1260      |
# |    iterations           | 19        |
# |    time_elapsed         | 29        |
# |    total_timesteps      | 37582     |
# | train/                  |           |
# |    approx_kl            | 0.1096039 |
# |    clip_fraction        | 0.238     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.456    |
# |    explained_variance   | 0.751     |
# |    learning_rate        | 0.0435    |
# |    loss                 | 0.353     |
# |    n_updates            | 180       |
# |    policy_gradient_loss | 0.0012    |
# |    value_loss           | 0.896     |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1263       |
# |    iterations           | 20         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 39560      |
# | train/                  |            |
# |    approx_kl            | 0.27255014 |
# |    clip_fraction        | 0.514      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.361     |
# |    explained_variance   | 0.234      |
# |    learning_rate        | 0.0435     |
# |    loss                 | 1.12       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.0458     |
# |    value_loss           | 2.33       |
# ----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 1264     |
# |    iterations           | 21       |
# |    time_elapsed         | 32       |
# |    total_timesteps      | 41538    |
# | train/                  |          |
# |    approx_kl            | 0.332101 |
# |    clip_fraction        | 0.457    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.404   |
# |    explained_variance   | 0.579    |
# |    learning_rate        | 0.0435   |
# |    loss                 | 0.298    |
# |    n_updates            | 200      |
# |    policy_gradient_loss | 0.0224   |
# |    value_loss           | 0.973    |
# --------------------------------------
# [I 2024-07-26 13:20:36,461] Trial 9 finished with value: 85.5 and parameters: {'n_steps': 1978, 'gamma': 0.9084301968180913, 'learning_rate': 0.04354193004063276, 'ent_coef': 0.07119297938707998}. Best is trial 7 with value: 500.0.
# Beste Hyperparameter:  {'n_steps': 1800, 'gamma': 0.8744836161035229, 'learning_rate': 0.027757382573945992, 'ent_coef': 0.03260042664169487}

# %% [markdown]
# ### Übernehmen der besten Hyperparameter ###

# %%
best_params = study.best_params

N_STEPS = best_params['n_steps']
GAMMA = best_params['gamma']
LEARNING_RATE = best_params['learning_rate']
ENT_COEF = best_params['ent_coef']

# %% [markdown]
# ### Finale Ausführung ###

# %%
# Erstellen des PPO-Modells
model = PPO('MlpPolicy', env, n_steps=N_STEPS, gamma=GAMMA, learning_rate=LEARNING_RATE, ent_coef=ENT_COEF, batch_size=1960, verbose=VERBOSE)
    
# Trainieren des Modells
model.learn(total_timesteps=TOTAL_TIMESTEPS)

# Evaluierung des Modells
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=N_EVAL_EPISODES)

print(f"Mean reward: {mean_reward}, std deviation: {std_reward}")

# Speicherung des Modells
model.save("./final_models/ppo_model")
# Out:
# c:\Users\orlando.d.tomanelli\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 1960, but because the `RolloutBuffer` is of size `n_steps * n_envs = 1800`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 1800
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=1800 and n_envs=1)
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | 21.4     |
# | time/              |          |
# |    fps             | 1313     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1800     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.2        |
# |    ep_rew_mean          | 23.2        |
# | time/                   |             |
# |    fps                  | 1248        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 3600        |
# | train/                  |             |
# |    approx_kl            | 0.009360698 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | -0.0181     |
# |    learning_rate        | 0.0278      |
# |    loss                 | 0.985       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00934    |
# |    value_loss           | 9.41        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.8        |
# |    ep_rew_mean          | 30.8        |
# | time/                   |             |
# |    fps                  | 1186        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 5400        |
# | train/                  |             |
# |    approx_kl            | 0.013594644 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.676      |
# |    explained_variance   | 0.297       |
# |    learning_rate        | 0.0278      |
# |    loss                 | 1.06        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 3.09        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 42.4       |
# |    ep_rew_mean          | 42.4       |
# | time/                   |            |
# |    fps                  | 968        |
# |    iterations           | 4          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 7200       |
# | train/                  |            |
# |    approx_kl            | 0.02038342 |
# |    clip_fraction        | 0.314      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.641     |
# |    explained_variance   | 0.39       |
# |    learning_rate        | 0.0278     |
# |    loss                 | 0.469      |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0265    |
# |    value_loss           | 1.48       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 59.3       |
# |    ep_rew_mean          | 59.3       |
# | time/                   |            |
# |    fps                  | 995        |
# |    iterations           | 5          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 9000       |
# | train/                  |            |
# |    approx_kl            | 0.05065731 |
# |    clip_fraction        | 0.313      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.557     |
# |    explained_variance   | 0.598      |
# |    learning_rate        | 0.0278     |
# |    loss                 | 0.293      |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.019     |
# |    value_loss           | 0.783      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.8        |
# |    ep_rew_mean          | 74.8        |
# | time/                   |             |
# |    fps                  | 1010        |
# |    iterations           | 6           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 10800       |
# | train/                  |             |
# |    approx_kl            | 0.121492974 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.51       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0278      |
# |    loss                 | 0.208       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.0148      |
# |    value_loss           | 0.457       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.2        |
# |    ep_rew_mean          | 85.2        |
# | time/                   |             |
# |    fps                  | 1036        |
# |    iterations           | 7           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 12600       |
# | train/                  |             |
# |    approx_kl            | 0.032166246 |
# |    clip_fraction        | 0.335       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.498      |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.0278      |
# |    loss                 | 0.197       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.0199      |
# |    value_loss           | 0.617       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1057         |
# |    iterations           | 8            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 14400        |
# | train/                  |              |
# |    approx_kl            | 0.0028034854 |
# |    clip_fraction        | 0.164        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.562       |
# |    explained_variance   | 0.258        |
# |    learning_rate        | 0.0278       |
# |    loss                 | 0.212        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00901     |
# |    value_loss           | 0.744        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 1070        |
# |    iterations           | 9           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 16200       |
# | train/                  |             |
# |    approx_kl            | 0.026352316 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.486      |
# |    explained_variance   | 0.505       |
# |    learning_rate        | 0.0278      |
# |    loss                 | 0.116       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 0.398       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | 127         |
# | time/                   |             |
# |    fps                  | 1078        |
# |    iterations           | 10          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 18000       |
# | train/                  |             |
# |    approx_kl            | 0.017099658 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.54       |
# |    explained_variance   | 0.376       |
# |    learning_rate        | 0.0278      |
# |    loss                 | 0.0898      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.00309     |
# |    value_loss           | 0.303       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 1089        |
# |    iterations           | 11          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 19800       |
# | train/                  |             |
# |    approx_kl            | 0.056618124 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 0.0278      |
# |    loss                 | 0.176       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.0145      |
# |    value_loss           | 0.379       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 149        |
# |    ep_rew_mean          | 149        |
# | time/                   |            |
# |    fps                  | 1097       |
# |    iterations           | 12         |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 21600      |
# | train/                  |            |
# |    approx_kl            | 0.04105669 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.518     |
# |    explained_variance   | 0.202      |
# |    learning_rate        | 0.0278     |
# |    loss                 | 0.387      |
# |    n_updates            | 110        |
# |    policy_gradient_loss | 0.00137    |
# |    value_loss           | 0.933      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | 151         |
# | time/                   |             |
# |    fps                  | 1105        |
# |    iterations           | 13          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 23400       |
# | train/                  |             |
# |    approx_kl            | 0.016693924 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.49       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0278      |
# |    loss                 | 0.117       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00443     |
# |    value_loss           | 0.317       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 154        |
# |    ep_rew_mean          | 154        |
# | time/                   |            |
# |    fps                  | 1113       |
# |    iterations           | 14         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 25200      |
# | train/                  |            |
# |    approx_kl            | 0.14495155 |
# |    clip_fraction        | 0.198      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.483     |
# |    explained_variance   | 0.619      |
# |    learning_rate        | 0.0278     |
# |    loss                 | 0.186      |
# |    n_updates            | 130        |
# |    policy_gradient_loss | 0.0169     |
# |    value_loss           | 0.343      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 160         |
# | time/                   |             |
# |    fps                  | 1118        |
# |    iterations           | 15          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 27000       |
# | train/                  |             |
# |    approx_kl            | 0.014552976 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.507      |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.0278      |
# |    loss                 | 0.0948      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00394    |
# |    value_loss           | 0.354       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 173         |
# |    ep_rew_mean          | 173         |
# | time/                   |             |
# |    fps                  | 1123        |
# |    iterations           | 16          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 28800       |
# | train/                  |             |
# |    approx_kl            | 0.016077636 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.516      |
# |    explained_variance   | 0.612       |
# |    learning_rate        | 0.0278      |
# |    loss                 | 0.0913      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 0.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 186         |
# |    ep_rew_mean          | 186         |
# | time/                   |             |
# |    fps                  | 1129        |
# |    iterations           | 17          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 30600       |
# | train/                  |             |
# |    approx_kl            | 0.023052452 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.538      |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.0278      |
# |    loss                 | 0.0439      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00106     |
# |    value_loss           | 0.176       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 189        |
# |    ep_rew_mean          | 189        |
# | time/                   |            |
# |    fps                  | 1133       |
# |    iterations           | 18         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 32400      |
# | train/                  |            |
# |    approx_kl            | 0.01251868 |
# |    clip_fraction        | 0.103      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.51      |
# |    explained_variance   | 0.847      |
# |    learning_rate        | 0.0278     |
# |    loss                 | 0.0684     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00032   |
# |    value_loss           | 0.157      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | 179          |
# | time/                   |              |
# |    fps                  | 1137         |
# |    iterations           | 19           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 34200        |
# | train/                  |              |
# |    approx_kl            | 0.0048071966 |
# |    clip_fraction        | 0.0446       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.53        |
# |    explained_variance   | 0.834        |
# |    learning_rate        | 0.0278       |
# |    loss                 | 0.0978       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 0.348        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 181         |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 1129        |
# |    iterations           | 20          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 36000       |
# | train/                  |             |
# |    approx_kl            | 0.003111876 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.523      |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 0.0278      |
# |    loss                 | 0.0675      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00256    |
# |    value_loss           | 0.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 187         |
# |    ep_rew_mean          | 187         |
# | time/                   |             |
# |    fps                  | 1112        |
# |    iterations           | 21          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 37800       |
# | train/                  |             |
# |    approx_kl            | 0.009815478 |
# |    clip_fraction        | 0.0893      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.541      |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0278      |
# |    loss                 | 0.00368     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.000916    |
# |    value_loss           | 0.0589      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 174       |
# |    ep_rew_mean          | 174       |
# | time/                   |           |
# |    fps                  | 1098      |
# |    iterations           | 22        |
# |    time_elapsed         | 36        |
# |    total_timesteps      | 39600     |
# | train/                  |           |
# |    approx_kl            | 0.0552735 |
# |    clip_fraction        | 0.463     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.615    |
# |    explained_variance   | 0.968     |
# |    learning_rate        | 0.0278    |
# |    loss                 | 0.0518    |
# |    n_updates            | 210       |
# |    policy_gradient_loss | 0.0256    |
# |    value_loss           | 0.181     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 174         |
# |    ep_rew_mean          | 174         |
# | time/                   |             |
# |    fps                  | 1097        |
# |    iterations           | 23          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 41400       |
# | train/                  |             |
# |    approx_kl            | 0.058003955 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.547      |
# |    explained_variance   | 0.455       |
# |    learning_rate        | 0.0278      |
# |    loss                 | 0.314       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00665    |
# |    value_loss           | 0.786       |
# -----------------------------------------
# Mean reward: 500.0, std deviation: 0.0
